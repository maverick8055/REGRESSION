# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data = pd.read_csv('Wine_Data.csv')

# %%
data.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      0    14.23        1.71  2.43               15.6        127
# 1      0    13.20        1.78  2.14               11.2        100
# 2      0    13.16        2.36  2.67               18.6        101
# 3      0    14.37        1.95  2.50               16.8        113
# 4      0    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
data.corr()
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# OD280/OD315          -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
data.groupby('Class').mean()
# Out:
#          Alcohol  Malic acid       Ash  Alcalinity of ash   Magnesium  \
# Class
# 0      13.744746    2.010678  2.455593          17.037288  106.338983
# 1      12.278732    1.932676  2.244789          20.238028   94.549296
# 2      13.153750    3.333750  2.437083          21.416667   99.312500
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# Class
# 0           2.840169    2.982373              0.290000         1.899322
# 1           2.258873    2.080845              0.363662         1.630282
# 2           1.678750    0.781458              0.447500         1.153542
#
#        Color intensity       Hue  OD280/OD315      Proline
# Class
# 0             5.528305  1.062034     3.157797  1115.711864
# 1             3.086620  1.056282     2.785352   519.507042
# 2             7.396250  0.682708     1.683542   629.895833

# %%
data.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.pairplot(data)

# %%
data.boxplot(figsize=(18,8))

# %%
#we can see that Malic acid , ash , alcalinity of ash, Magnesium , proanthocynisis, color intensity , hue
#so we need to remove outlier
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
data = remove_outlier(data,"Malic acid")
data = remove_outlier(data,"Ash")
data = remove_outlier(data,"Alcalinity of ash")
data = remove_outlier(data,"Magnesium")
data = remove_outlier(data,"Proanthocyanins")
data = remove_outlier(data,"Color intensity")
data = remove_outlier(data,"Hue")
data = remove_outlier(data,"Nonflavanoid phenols")

# %%
data.boxplot(return_type='axes',figsize=(18,8))

# %%
Y = data.loc[:,'Class'].values
X = data.loc[:,'Alcohol':'Proline'].values

# %%
#we split the dataset into a test and training set
train_x, test_x, train_y, test_y = train_test_split(X,Y , test_size=0.25, random_state=0)
clf = LogisticRegression(solver='lbfgs',multi_class='multinomial')
clf.fit(train_x, train_y)
clf.score(test_x, test_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 0.9736842105263158

# %%
test_y
# Out:
# array([2, 1, 0, 1, 0, 1, 0, 1, 1, 1, 2, 0, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1], dtype=int64)
